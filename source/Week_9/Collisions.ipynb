# %%
from binder import Binder, start

def collision(data):
    for i in range(len(data)-1):
        rec1 = data[i]
        for j in range(i+1, len(data)):
            rec2 = data[j]
            if rec1["x"] > rec2["x"] + 20 or rec2["x"] > rec1["x"] + 20:
                continue
            if rec1["y"] + 20 < rec2["y"] or rec2["y"] + 20 < rec1["y"]:
                continue
            data[i]["deleted"] = True
            data[j]["deleted"] = True
    return data

start(51, collision)
# Out:
# <canvas id="game" width="400px" height="400px" style="background: url(https://i.pinimg.com/564x/68/72/6a/68726ab4f1e421b7dd328f7917e7be7a.jpg);"></canvas>        <img id="sprites" style="display:none" src="https://images-wixmp-ed30a86b8c4ca887773594c2.wixmp.com/f/da113cba-7663-4d97-9cd6-f832ffc6f79f/d1dpbih-c9e042fb-c81a-43c6-9652-2f1fabb57dad.gif?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..q6ov5px5-ayc6XGUII47foBqdq0vkyMSKc-4r0I5L0k"/>
